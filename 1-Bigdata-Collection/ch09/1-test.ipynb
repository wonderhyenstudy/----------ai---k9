# %%
# 구글 코랩(Colab)에서 바로 실행 가능 — pandas, matplotlib 기본 설치됨
import urllib.request   # URL로 요청을 보내는 기본 모듈
import urllib.parse     # 한글 검색어를 URL용으로 인코딩
import json             # JSON 문자열 ↔ 파이썬 딕셔너리 변환
import datetime         # 시간 기록

# %%
import urllib.request

res = urllib.request.urlopen("https://www.naver.com")
print(type(res))     # <class 'http.client.HTTPResponse'>
print(res.status)    # 200  → 요청 성공
print("--- 헤더 정보 ---")
for h in res.getheaders():
    print(h)
# Out:
# <class 'http.client.HTTPResponse'>
# 200
# --- 헤더 정보 ---
# ('Date', 'Thu, 04 Jun 2026 02:20:45 GMT')
# ('content-type', 'text/html; charset=UTF-8')
# ('transfer-encoding', 'chunked')
# ('set-cookie', 'PM_CK_loc=6a99d2fc1b5471d9d14cea36ec9cb8ccbc593048dad883183ee247e5610d9706; Expires=Fri, 05 Jun 2026 02:20:45 GMT; Path=/; HttpOnly')
# ('cache-control', 'no-cache, no-store, must-revalidate')
# ('pragma', 'no-cache')
# ('x-frame-options', 'DENY')
# ('strict-transport-security', 'max-age=63072000; includeSubdomains')
# ('referrer-policy', 'unsafe-url')
# ('server', 'nfront')
# ('connection', 'close')

# %%
import urllib.request
import urllib.parse

# 1) https://developers.naver.com 에서 애플리케이션 등록 후 발급
client_id = ""
client_secret = ""

encText = urllib.parse.quote("애플")   # 한글 검색어 → URL 인코딩 필수
url = "https://openapi.naver.com/v1/search/blog?query=" + encText

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id", client_id)        # 인증키를 헤더에 실어 보냄
request.add_header("X-Naver-Client-Secret", client_secret)

response = urllib.request.urlopen(request)
if response.getcode() == 200:
    body = response.read().decode("utf-8")   # 바이트 → 문자열
    print(body)
else:
    print("Error Code:", response.getcode())
# Out:
# {
# 	"lastBuildDate":"Thu, 04 Jun 2026 11:35:06 +0900",
# 	"total":8165815,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"뉴욕 여행 준비는 빅<b>애플<\/b>패스 뉴욕 3대 패스 비교 및 추천",
# 			"link":"https:\/\/blog.naver.com\/be_ok-\/224294982259",
# 			"description":"뉴욕 여행 준비는 빅<b>애플<\/b>패스 뉴욕 3대 패스 비교 및 추천 안녕하세요! 여행 인플루언서 홍지구입니다... 지구가 찾아봤던 뉴욕 3대 패스를 한 번 비교해보고 지구가 선택한 빅<b>애플<\/b>패스가 어떤 장점이... ",
# 			"bloggername":"오늘도, 지구 여행",
# 			"bloggerlink":"blog.naver.com\/be_ok-",
# 			"postdate":"20260524"
# 		},
# 		{
# 			"title":"아오모리 골프여행 | <b>애플<\/b>랜드 온천호텔 투숙 후기",
# 			"link":"https:\/\/blog.naver.com\/trip_pro\/224298640835",
# 			"description":"이번에 소개해 드릴 곳은 아오모리 골프여행에서 한국인들에게 가장 인기 있는 온천호텔 <b>애플<\/b>랜드입니다. 많은 분들이 궁금해합니다. 왜 아오모리로 골프여행을 가면 시내 호텔이 아닌 <b>애플<\/b>랜드로만 가느냐고... ",
# 			"bloggername":"바로여행 최팀장의 골프여행",
# 			"bloggerlink":"blog.naver.com\/trip_pro",
# 			"postdate":"20260528"
# 		},
# 		{
# 			"title":"<b>애플<\/b>워치 울트라3 추천 리뷰 명품 스포츠 아웃도어 스마트워치",
# 			"link":"https:\/\/blog.naver.com\/happypanchok\/224301214586",
# 			"description":"<b>애플<\/b>워치 울트라3 추천 리뷰 명품 스포츠 아웃도어 스마트워치 스마트워치, 제대로 바꿨어요... 그러다 <b>애플<\/b>워치 울트라3를 알게 됐습니다. 기존에 쓰던 <b>애플<\/b>워치와 나란히 두고 보니 크기부터가 완전히... ",
# 			"bloggername":"애드공감",
# 			"bloggerlink":"blog.naver.com\/happypanchok",
# 			"postdate":"20260531"
# 		},
# 		{
# 			"title":"<b>애플<\/b>수박 키우기 모종심기 심는방법 수확시기",
# 			"link":"https:\/\/blog.naver.com\/luv_wintermoon\/224302421880",
# 			"description":"<b>애플<\/b>수박 키우기 모종심기 심는방법 수확시기 총정리! 부쩍 더워진 날씨에 시원하고 달콤한 과일이 절로 생각나는 계절인데요. 오늘은 요즘 미니멀한 홈가드닝 작물로 가장 핫한 '<b>애플<\/b>수박' 이야기를... ",
# 			"bloggername":"Odo house",
# 			"bloggerlink":"blog.naver.com\/luv_wintermoon",
# 			"postdate":"20260601"
# 		},
# 		{
# 			"title":"<b>애플<\/b>워치 배터리 성능 확인 효율적으로 사용하는 노하우",
# 			"link":"https:\/\/blog.naver.com\/saporo2373\/224302496597",
# 			"description":"<b>애플<\/b>워치를 오래 쓰다 보면 어느 순간부터 충전 속도는 그대로인데 사용 시간만 눈에 띄게 줄어드는 시점이 옵니다. 이럴 때 가장 먼저 점검해야 할 부분이 바로 <b>애플<\/b>워치 배터리 성능 확인입니다. 현재... ",
# 			"bloggername":"메피의 알기 쉬운 IT 꿀팁",
# 			"bloggerlink":"blog.naver.com\/saporo2373",
# 			"postdate":"20260601"
# 		},
# 		{
# 			"title":"울산아이폰수리 과잉수리 없이 깔끔했던 픽스<b>애플<\/b> 후기",
# 			"link":"https:\/\/blog.naver.com\/zmfltmvlfhf2\/224291212156",
# 			"description":"픽스<b>애플<\/b> 후기 퇴근하던 길에 실수로 아이폰을 떨어뜨렸는데, 화면이 그대로 바닥 모서리에 부딪히면서... 픽스<b>애플<\/b>이었습니다. 울산아이폰수리 픽스<b>애플<\/b>은 무엇보다 광고 느낌보다 실제 방문 후기들이 많았고... ",
# 			"bloggername":"1800-1773 컴스마일",
# 			"bloggerlink":"blog.naver.com\/zmfltmvlfhf2",
# 			"postdate":"20260520"
# 		},
# 		{
# 			"title":"<b>애플<\/b>수박 키우기, 모종 심고 순치기 재배 팁",
# 			"link":"https:\/\/blog.naver.com\/tameones\/224299794651",
# 			"description":"<b>애플<\/b>수박 키우기 <b>애플<\/b>수박 모종 심고 순치기 재배 팁 처음 <b>애플<\/b>수박 키우기를 시작했을 때는 줄기만 길게 뻗고 열매는 생각보다 잘 안 달려서 속상했던 기억이 있습니다. 특히 <b>애플<\/b>수박순치기라는 걸 몰랐을... ",
# 			"bloggername":"길들이기's 텃밭이야기 (feat. 건강이야기)",
# 			"bloggerlink":"blog.naver.com\/tameones",
# 			"postdate":"20260529"
# 		},
# 		{
# 			"title":"<b>애플<\/b>워치 산소포화도 심박수 심전도 기능 활용 방법",
# 			"link":"https:\/\/blog.naver.com\/moimoi1357\/224301842013",
# 			"description":"저 역시 순토와 <b>애플<\/b>의 스마트워치를 번갈아 사용하면서 운동 기록이나 수면 분석뿐만 아니라 평소 몸의 상태를 확인하는 용도로도 자주 활용하고 있습니다. 일상에서 유용한 <b>애플<\/b>워치 기능 중에는 산소포화도... ",
# 			"bloggername":"모이모이의 IT 이야기",
# 			"bloggerlink":"blog.naver.com\/moimoi1357",
# 			"postdate":"20260531"
# 		},
# 		{
# 			"title":"“맥북이 이 가격이면 반칙 아닌가”… <b>애플<\/b> 맥북 네오가 터진... ",
# 			"link":"https:\/\/blog.naver.com\/cooljakey\/224305353891",
# 			"description":"“맥북이 이 가격이면 반칙 아닌가”… <b>애플<\/b> 맥북 네오가 터진 진짜 이유 레드한량입니다. <b>애플<\/b> 제품을 떠올리면 늘 따라붙는 말이 있습니다. 예쁘지만 비싸다, 좋지만 부담스럽다, 결국 <b>애플<\/b> 생태계에... ",
# 			"bloggername":"레드한량의 전기차 블로그",
# 			"bloggerlink":"blog.naver.com\/cooljakey",
# 			"postdate":"20260604"
# 		},
# 		{
# 			"title":"페라리 전기차 '루체', &quot;조니 아이브가 그린 <b>애플<\/b>카?&quot;",
# 			"link":"https:\/\/blog.naver.com\/yjg01212\/224298175200",
# 			"description":"페라리 전기차 루체 &quot;조니 아이브가 그린 <b>애플<\/b>카?&quot; 마라넬로의 V12 엔진음이 익숙한 분들에게는 묘한... 직후부터 '<b>애플<\/b>카가 이런 모습일까'라는 반응이 쏟아지고 있습니다. 페라리 루체 디자인, 단일... ",
# 			"bloggername":"IT's ivory",
# 			"bloggerlink":"blog.naver.com\/yjg01212",
# 			"postdate":"20260527"
# 		}
# 	]
# }

# %%
import os, urllib.request, urllib.parse, datetime, json

client_id = ""
client_secret = ""

def getRequestUrl(url):                       # [CODE 1] 공통 요청 함수
    req = urllib.request.Request(url)
    req.add_header("X-Naver-Client-Id", client_id)
    req.add_header("X-Naver-Client-Secret", client_secret)
    try:
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            print("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode("utf-8")
    except Exception as e:
        print(e); return None

def getNaverSearch(node, srcText, start, display):   # [CODE 2] 검색 요청 조립
    base = "https://openapi.naver.com/v1/search"
    node = "/%s.json" % node
    params = "?query=%s&start=%s&display=%s" % (urllib.parse.quote(srcText), start, display)
    responseDecode = getRequestUrl(base + node + params)
    return None if responseDecode is None else json.loads(responseDecode)

def getPostData(post, jsonResult, cnt):              # [CODE 3] 필요한 항목만 추출
    pDate = datetime.datetime.strptime(post['postdate'], '%Y%m%d').strftime('%Y-%m-%d')
    jsonResult.append({'cnt': cnt, 'title': post['title'],
                       'description': post['description'],
                       'link': post['bloggerlink'], 'pDate': pDate})

def main():
    node = 'blog'
    srcText = input('검색어를 입력하세요: ')
    cnt = 0; jsonResult = []
    jsonResponse = getNaverSearch(node, srcText, 1, 100)
    total = jsonResponse['total']
    while jsonResponse is not None and jsonResponse['display'] != 0:
        for post in jsonResponse['items']:
            cnt += 1
            getPostData(post, jsonResult, cnt)
        start = jsonResponse['start'] + jsonResponse['display']
        jsonResponse = getNaverSearch(node, srcText, start, 100)
    print('전체 검색: %d 건 / 수집: %d 건' % (total, cnt))
    with open('%s_naver_%s.json' % (srcText, node), 'w', encoding='utf8') as f:
        f.write(json.dumps(jsonResult, indent=4, ensure_ascii=False))
    print('저장 완료')

if __name__ == '__main__':
    main()
# Out:
# [2026-06-04 11:36:49.964265] Url Request Success
# [2026-06-04 11:36:50.256024] Url Request Success
# [2026-06-04 11:36:50.391255] Url Request Success
# [2026-06-04 11:36:50.683886] Url Request Success
# [2026-06-04 11:36:50.829895] Url Request Success
# [2026-06-04 11:36:51.120569] Url Request Success
# [2026-06-04 11:36:51.406262] Url Request Success
# [2026-06-04 11:36:51.534228] Url Request Success
# [2026-06-04 11:36:51.870196] Url Request Success
# [2026-06-04 11:36:51.993611] Url Request Success
# HTTP Error 400: Bad Request
# 전체 검색: 898650 건 / 수집: 1000 건
# 저장 완료

# %%
import urllib.request, urllib.parse, json, ssl, platform, datetime
import pandas as pd, numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

API_KEY = ""   # data.go.kr 에서 발급 (Decoding 키 사용)

SEOUL_DISTRICTS = {"종로구": 110, "중구": 140, "용산구": 170, "성동구": 200,
                   "강남구": 680, "서초구": 650, "송파구": 710}   # 일부 예시

context = ssl.create_default_context()
context.set_ciphers('DEFAULT@SECLEVEL=1')   # 일부 공공기관 구형 SSL 대응

def set_korean_font():                       # 한글 폰트 (OS 자동 감지)
    sysname = platform.system()
    path = {"Windows": "C:/Windows/Fonts/malgun.ttf",
            "Darwin": "/System/Library/Fonts/Supplemental/AppleGothic.ttf"}\
           .get(sysname, "/usr/share/fonts/truetype/nanum/NanumGothic.ttf")
    plt.rcParams["font.family"] = fm.FontProperties(fname=path).get_name()
    plt.rcParams["axes.unicode_minus"] = False
set_korean_font()

def fetch(searchYearCd, siDo, guGun, numOfRows=100, pageNo=1):
    base = "https://apis.data.go.kr/B552061/frequentzoneBicycle/getRestFrequentzoneBicycle"
    params = {"ServiceKey": API_KEY, "searchYearCd": searchYearCd, "siDo": siDo,
              "guGun": guGun, "type": "json", "numOfRows": numOfRows, "pageNo": pageNo}
    url = base + "?" + urllib.parse.urlencode(params)   # 파라미터 자동 인코딩
    req = urllib.request.Request(url)
    try:
        text = urllib.request.urlopen(req, context=context).read().decode("utf-8")
    except Exception as e:
        print("오류:", e); return None
    if not text.strip():
        print("응답이 비어있음"); return None
    return json.loads(text)

# 강남구(680) 2023년 사고 다발 지역 수집 예시
data = fetch("2023", "11", "680")
if data and data.get("items"):
    df = pd.DataFrame(data["items"]["item"])
    print(df.head())
    df["occrrnc_cnt"] = pd.to_numeric(df["occrrnc_cnt"])  # 발생건수 숫자화
    plt.figure(figsize=(10, 5))
    plt.bar(df["spot_nm"], df["occrrnc_cnt"], color="skyblue")
    plt.title("2023 서울 강남구 자전거 사고 다발지역")
    plt.xticks(rotation=45, ha="right"); plt.tight_layout()
    plt.show()
# Out:
#    afos_fid  afos_id      bjd_cd   spot_cd sido_sgg_nm                spot_nm  \
# 0   6929976  2024046  1168011800  11680001     서울 강남구1  서울 강남구 도곡동(한티역교차로 부근)
#
#    occrrnc_cnt  caslt_cnt  dth_dnv_cnt  se_dnv_cnt  sl_dnv_cnt  wnd_dnv_cnt  \
# 0            5          5            0           1           3            1
#
#                                            geom_json            lo_crd  \
# 0  {"type":"Polygon","coordinates":[[[127.0550824...  127.053285859967
#
#             la_crd
# 0  37.496440829904

# %%
import pymysql

con = pymysql.connect(
    host='127.0.0.1',
    user='webuser',
    password='webuser',
    database='webdb',
    charset='utf8')
print('DB 연결 성공!')

cur = con.cursor()   # 커서 생성 (SQL 실행 통로)
# Out:
# DB 연결 성공!

# %%
sql = """
CREATE TABLE news_data (
    id INT AUTO_INCREMENT PRIMARY KEY,
    cnt INT,
    title VARCHAR(255),
    description TEXT,
    link VARCHAR(255),
    pDate DATE
);
"""
cur.execute(sql)
print('테이블 생성 성공!')
# Out:
# 테이블 생성 성공!

# %%
CREATE TABLE news_data (
    id INT AUTO_INCREMENT PRIMARY KEY,
    cnt INT,
    title VARCHAR(255),
    description TEXT,
    link VARCHAR(255),
    pDate DATE
);

# %%
import urllib.request, urllib.parse, datetime, json
import pymysql

# 네이버 API 키 설정
client_id = ""
client_secret = ""

def getRequestUrl(url):
    req = urllib.request.Request(url)
    req.add_header("X-Naver-Client-Id", client_id)
    req.add_header("X-Naver-Client-Secret", client_secret)
    try:
        response = urllib.request.urlopen(req)
        if response.getcode() == 200:
            return response.read().decode("utf-8")
    except Exception as e:
        print(e); return None

def getNaverSearch(node, srcText, start, display):
    base = "https://openapi.naver.com/v1/search"
    node = "/%s.json" % node
    params = "?query=%s&start=%s&display=%s" % (urllib.parse.quote(srcText), start, display)
    responseDecode = getRequestUrl(base + node + params)
    return None if responseDecode is None else json.loads(responseDecode)

def saveToDB(post, cnt, cursor):
    # HTML 태그 제거 (간단하게)
    title = post['title'].replace('<b>', '').replace('</b>', '')
    description = post['description'].replace('<b>', '').replace('</b>', '')
    pDate = datetime.datetime.strptime(post['pubDate'], '%a, %d %b %Y %H:%M:%S %z').strftime('%Y-%m-%d')
    
    sql = "INSERT INTO news_data (cnt, title, description, link, pDate) VALUES (%s, %s, %s, %s, %s)"
    cursor.execute(sql, (cnt, title, description, post['link'], pDate))

def main():
    # DB 연결
    conn = pymysql.connect(host='localhost', user='webuser', password='webuser', db='webdb', charset='utf8')
    cursor = conn.cursor()

    node = 'news' # 블로그에서 뉴스 검색으로 변경
    srcText = input('검색어를 입력하세요: ')
    cnt = 0
    
    # 네이버 뉴스 API는 start가 1000이 최대이므로 루프 제한 필요
    start = 1
    while start <= 1000:
        jsonResponse = getNaverSearch(node, srcText, start, 100)
        if jsonResponse is None or 'items' not in jsonResponse or not jsonResponse['items']:
            break
            
        for post in jsonResponse['items']:
            cnt += 1
            saveToDB(post, cnt, cursor)
            
        conn.commit() # 주기적으로 저장
        print(f"{start} 건 단위 저장 완료")
        
        start += 100
        if start > jsonResponse['total']: break

    cursor.close()
    conn.close()
    print('모든 데이터 저장 완료')

if __name__ == '__main__':
    main()
# Out:
# C:\Users\it\AppData\Local\Temp\ipykernel_6212\2440992288.py:66: DeprecationWarning: 'db' is deprecated, use 'database'
#   main()
# 1 건 단위 저장 완료
# 101 건 단위 저장 완료
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# Cell In[8], line 66
#      62     conn.close()
#      63     print('모든 데이터 저장 완료')
#      64
#      65 if __name__ == '__main__':
# ---> 66     main()
#
# Cell In[8], line 53, in main()
#      49             break
#      50
#      51         for post in jsonResponse['items']:
#      52             cnt += 1
# ---> 53             saveToDB(post, cnt, cursor)
#      54
#      55         conn.commit() # 주기적으로 저장
#      56         print(f"{start} 건 단위 저장 완료")
#
# Cell In[8], line 33, in saveToDB(post, cnt, cursor)
#      29     description = post['description'].replace('<b>', '').replace('</b>', '')
#      30     pDate = datetime.datetime.strptime(post['pubDate'], '%a, %d %b %Y %H:%M:%S %z').strftime('%Y-%m-%d')
#      31
#      32     sql = "INSERT INTO news_data (cnt, title, description, link, pDate) VALUES (%s, %s, %s, %s, %s)"
# ---> 33     cursor.execute(sql, (cnt, title, description, post['link'], pDate))
#
# File d:\000-0-0-Big Data with Python Fundamentals Data Collection, Storage, Analysis, Visualization, and AI Modeling\1-Bigdata-Collection\venv\Lib\site-packages\pymysql\cursors.py:159, in Cursor.execute(self, query, args)
#     155     pass
#     157 query = self.mogrify(query, args)
# --> 159 result = self._query(query)
#     160 self._executed = query
#     161 return result
#
# File d:\000-0-0-Big Data with Python Fundamentals Data Collection, Storage, Analysis, Visualization, and AI Modeling\1-Bigdata-Collection\venv\Lib\site-packages\pymysql\cursors.py:330, in Cursor._query(self, q)
#     328 conn = self._get_db()
#     329 self._clear_result()
# --> 330 conn.query(q)
#     331 self._do_get_result()
#     332 return self.rowcount
#
# File d:\000-0-0-Big Data with Python Fundamentals Data Collection, Storage, Analysis, Visualization, and AI Modeling\1-Bigdata-Collection\venv\Lib\site-packages\pymysql\connections.py:582, in Connection.query(self, sql, unbuffered)
#     580     sql = sql.encode(self.encoding, "surrogateescape")
#     581 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 582 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     583 return self._affected_rows
#
# File d:\000-0-0-Big Data with Python Fundamentals Data Collection, Storage, Analysis, Visualization, and AI Modeling\1-Bigdata-Collection\venv\Lib\site-packages\pymysql\connections.py:847, in Connection._read_query_result(self, unbuffered)
#     845     result.init_unbuffered_query()
#     846 else:
# --> 847     result.read()
#     848 self._result = result
#     849 if result.server_status is not None:
#
# File d:\000-0-0-Big Data with Python Fundamentals Data Collection, Storage, Analysis, Visualization, and AI Modeling\1-Bigdata-Collection\venv\Lib\site-packages\pymysql\connections.py:1245, in MySQLResult.read(self)
#    1243 def read(self):
#    1244     try:
# -> 1245         first_packet = self.connection._read_packet()
#    1247         if first_packet.is_ok_packet():
#    1248             self._read_ok_packet(first_packet)
#
# File d:\000-0-0-Big Data with Python Fundamentals Data Collection, Storage, Analysis, Visualization, and AI Modeling\1-Bigdata-Collection\venv\Lib\site-packages\pymysql\connections.py:803, in Connection._read_packet(self, packet_type)
#     801     if self._result is not None and self._result.unbuffered_active is True:
#     802         self._result.unbuffered_active = False
# --> 803     packet.raise_for_error()
#     804 return packet
#
# File d:\000-0-0-Big Data with Python Fundamentals Data Collection, Storage, Analysis, Visualization, and AI Modeling\1-Bigdata-Collection\venv\Lib\site-packages\pymysql\protocol.py:219, in MysqlPacket.raise_for_error(self)
#     217 if DEBUG:
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File d:\000-0-0-Big Data with Python Fundamentals Data Collection, Storage, Analysis, Visualization, and AI Modeling\1-Bigdata-Collection\venv\Lib\site-packages\pymysql\err.py:154, in raise_mysql_exception(data)
#     152 if errorclass is None:
#     153     errorclass = InternalError if errno < 1000 else OperationalError
# --> 154 raise errorclass(errno, errval, sqlstate=sqlstate)
#
# DataError: (1406, "Data too long for column 'link' at row 1")
